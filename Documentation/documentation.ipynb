# %% [markdown]
# # Process ETL with GCP and DBT
# * ### Client: Nova Drive Motors
# * ### Data Engineer: Michel Souza Santana
# * ##### Date Start: 02/07/2024
# * ##### Date Finish:

# %% [markdown]
# ***

# %% [markdown]
# ![NovaDrive-Motors_ETL_GCP.jpg](attachment:NovaDrive-Motors_ETL_GCP.jpg)
